# %%
import pandas as pd
import numpy as np

# %% [markdown]
# JSON - JavaScript Object Notation -  текстовый формат обмена данными, основанный на JavaScript.

# %%
#В ходе урока мы создаем документика формата Json и подгружаем его
df = pd.read_json('Z:\\Programming\\DataSciense\\Stepik_Pandas_Numpy\\Step_4.4.json')
df
# Out:
#   surname  name  age    city
# 0  Ivanov  Ivan   18   Kazan
# 1  Ivanov  Petr   36  Moscow

# %% [markdown]
# - Сохранение в формат Json

# %%
data = [['Girev', 'Andrey', 'ВИП', 2815, 29, 58, 6358, 'Moscow', 'Xiaomi'],
       ['Bykin', 'Stas', 'Все за 300', 3634, 37, 78, 602, 'Kazan',
        'Samsung'],
       ['Ivanov', 'Alex', 'Всё за 800', 410, 47, 81, 3582, 'Moscow',
        'Huawei'],
       ['Andreev', 'Sergey', 'Всё за 500', 1981, 75, 98, 5442, 'Kazan',
        'Apple'],
       ['Girev', 'Stas', 'Всё за 800', 4969, 43, 61, 8510, 'Moscow',
        'Samsung'],
       ['Bykin', 'Andrey', 'Всё за 500', 4308, 49, 39, 2525, 'Moscow',
        'Xiaomi'],
       ['Kozlov', 'Igor', 'Всё за 800', 300, 60, 31, 8543, 'Yakutsk',
        'Samsung'],
       ['Girev', 'Alex', 'Промо', 4199, 47, 90, 3925, 'Kazan', 'Apple'],
       ['Petrov', 'Nikolay', 'ВИП', 4810, 72, 88, 7188, 'Moscow',
        'Apple'],
       ['Andreev', 'Sergey', 'Всё за 800', 4118, 52, 53, 419, 'Yakutsk',
        'Apple'],
       ['Smolov', 'Stas', 'Промо', 1991, 28, 67, 5016, 'Kazan', 'Xiaomi'],
       ['Girev', 'Igor', 'Корпоративный', 1430, 69, 19, 9520, 'Yakutsk',
        'Samsung'],
       ['Kozlov', 'Andrey', 'Корпоративный', 113, 71, 82, 2785, 'Kazan',
        'Apple'],
       ['Ivanov', 'Sergey', 'Промо', 3394, 39, 12, 2718, 'Yakutsk',
        'Xiaomi'],
       ['Smolov', 'Sergey', 'Всё за 250 (архив)', 3493, 32, 6, 8959,
        'Yakutsk', 'Huawei'],
       ['Kozlov', 'Stas', 'Всё за 800', 4565, 59, 82, 3168, 'Moscow',
        'Apple'],
       ['Vlasov', 'Andrey', 'Всё за 800', 3192, 29, 74, 2852, 'Yakutsk',
        'Xiaomi'],
       ['Smolov', 'Alex', 'Корпоративный', 3764, 71, 22, 2768, 'Moscow',
        'Huawei'],
       ['Vlasov', 'Sergey', 'Всё за 800', 3816, 28, 35, 5734,
        'Vladivostok', 'Apple'],
       ['Bykin', 'Alex', 'Промо', 817, 65, 34, 2131, 'Vladivostok',
        'Samsung'],
       ['Andreev', 'Nikolay', 'Всё за 500', 385, 49, 62, 1815, 'Kazan',
        'Xiaomi'],
       ['Bykin', 'Igor', 'Всё за 500', 2642, 38, 11, 3787, 'Moscow',
        'Xiaomi'],
       ['Girev', 'Sergey', 'Все за 300', 4230, 62, 68, 5512,
        'Vladivostok', 'Samsung'],
       ['Bykin', 'Sergey', 'Всё за 800', 4100, 48, 39, 227, 'Moscow',
        'Xiaomi'],
       ['Girev', 'Stas', 'Все за 300', 3371, 53, 24, 7946, 'Kazan',
        'Apple'],
       ['Smolov', 'Sergey', 'Корпоративный', 3577, 70, 71, 8847,
        'Yakutsk', 'Huawei'],
       ['Mezov', 'Nikolay', 'Всё за 250 (архив)', 2742, 28, 19, 7115,
        'Yakutsk', 'Huawei'],
       ['Smolov', 'Stas', 'Всё за 500', 2644, 41, 33, 8341, 'Moscow',
        'Xiaomi'],
       ['Vlasov', 'Andrey', 'Всё за 500', 4725, 26, 93, 9441,
        'Vladivostok', 'Xiaomi'],
       ['Ivanov', 'Nikolay', 'Всё за 500', 2785, 41, 5, 2901, 'Moscow',
        'Samsung']]

df = pd.DataFrame(data, columns = ['surname', 'name', 'tarif', 'balance', 'age', 
                                   'sms', 'voice', 'city', 'phone'])

# %%
df
# Out:
#     surname     name               tarif  balance  age  sms  voice  \
# 0     Girev   Andrey                 ВИП     2815   29   58   6358
# 1     Bykin     Stas          Все за 300     3634   37   78    602
# 2    Ivanov     Alex          Всё за 800      410   47   81   3582
# 3   Andreev   Sergey          Всё за 500     1981   75   98   5442
# 4     Girev     Stas          Всё за 800     4969   43   61   8510
# 5     Bykin   Andrey          Всё за 500     4308   49   39   2525
# 6    Kozlov     Igor          Всё за 800      300   60   31   8543
# 7     Girev     Alex               Промо     4199   47   90   3925
# 8    Petrov  Nikolay                 ВИП     4810   72   88   7188
# 9   Andreev   Sergey          Всё за 800     4118   52   53    419
# 10   Smolov     Stas               Промо     1991   28   67   5016
# 11    Girev     Igor       Корпоративный     1430   69   19   9520
# 12   Kozlov   Andrey       Корпоративный      113   71   82   2785
# ...

# %%
df.to_json('Z:\\Programming\\DataSciense\\Stepik_Pandas_Numpy\\Step_4.4._output.json')

# %% [markdown]
# Когда мы откроем, получившийся файл, мы увидим, что у нас получился файл в одну строку.
# Для преобразования есть специальные всякие разные сервисы, ссылки:
# - https://jsonformatter.org/json-pretty-print
# - http://jsonviewer.stack.hu/

# %% [markdown]
# - Параметр orient
#
# По-умолчанию у параметра orient установлено значение "columns", поэтому запись в json идет по колонкам.
#
# Мы устанавливаем значение параметра "records", что с английского переводится как записи, т.е. строки.

# %%
df.to_json('Z:\\Programming\\DataSciense\\Stepik_Pandas_Numpy\\Step_4.4._output_orient.json', 
           orient = 'records')

# %% [markdown]
# - Практика Json

# %% [markdown]
# Перейдем на сайт: https://openweathermap.org/
#
# Далее идем в раздел API(Если вы видите раздел API, то оттуда можно получить различные данные)
#
# Api doc
#
# Api Call

# %% [markdown]
# Перейдем на сайт: https://www.alphavantage.co/documentation/
#
# Кликаем на ссылочки как на скриншоте и видим как раз таки информацию в формате Json.

# %% [markdown]
# - Как нам скачать данные?

# %%
#Сначала пойдем кустарным способом, просто скопируем
#Забегу вперед, позже будет показан способ без этой дичи
data = {
    "Meta Data": {
        "1. Information": "Intraday (5min) open, high, low, close prices and volume",
        "2. Symbol": "IBM",
        "3. Last Refreshed": "2023-02-09 19:45:00",
        "4. Interval": "5min",
        "5. Output Size": "Compact",
        "6. Time Zone": "US/Eastern"
    },
    "Time Series (5min)": {
        "2023-02-09 19:45:00": {
            "1. open": "133.7500",
            "2. high": "133.7500",
            "3. low": "133.7500",
            "4. close": "133.7500",
            "5. volume": "100"
        },
        "2023-02-09 19:25:00": {
            "1. open": "133.7500",
            "2. high": "133.7500",
            "3. low": "133.7500",
            "4. close": "133.7500",
            "5. volume": "1101"
        },
        "2023-02-09 17:30:00": {
            "1. open": "133.7500",
            "2. high": "133.7500",
            "3. low": "133.7500",
            "4. close": "133.7500",
            "5. volume": "1639"
        },
        "2023-02-09 17:25:00": {
            "1. open": "134.0000",
            "2. high": "134.0000",
            "3. low": "134.0000",
            "4. close": "134.0000",
            "5. volume": "152"
        },
        "2023-02-09 17:20:00": {
            "1. open": "134.0000",
            "2. high": "134.0000",
            "3. low": "134.0000",
            "4. close": "134.0000",
            "5. volume": "104"
        },
        "2023-02-09 16:40:00": {
            "1. open": "133.7000",
            "2. high": "133.7000",
            "3. low": "133.7000",
            "4. close": "133.7000",
            "5. volume": "294"
        },
        "2023-02-09 16:15:00": {
            "1. open": "133.5000",
            "2. high": "133.8500",
            "3. low": "133.5000",
            "4. close": "133.8500",
            "5. volume": "1576"
        },
        "2023-02-09 16:10:00": {
            "1. open": "133.7500",
            "2. high": "133.7500",
            "3. low": "133.7500",
            "4. close": "133.7500",
            "5. volume": "7469"
        },
        "2023-02-09 16:05:00": {
            "1. open": "133.7500",
            "2. high": "133.7500",
            "3. low": "133.7500",
            "4. close": "133.7500",
            "5. volume": "175932"
        },
        "2023-02-09 16:00:00": {
            "1. open": "133.8950",
            "2. high": "133.9000",
            "3. low": "133.6300",
            "4. close": "134.9500",
            "5. volume": "3425"
        },
        "2023-02-09 08:00:00": {
            "1. open": "135.0000",
            "2. high": "135.0000",
            "3. low": "135.0000",
            "4. close": "135.0000",
            "5. volume": "999"
        },
        "2023-02-09 07:55:00": {
            "1. open": "135.1000",
            "2. high": "135.1000",
            "3. low": "135.1000",
            "4. close": "135.1000",
            "5. volume": "1160"
        }
    }
}

# %%
data[
    'Time Series (5min)'
]
# Out:
# {'2023-02-09 19:45:00': {'1. open': '133.7500',
#   '2. high': '133.7500',
#   '3. low': '133.7500',
#   '4. close': '133.7500',
#   '5. volume': '100'},
#  '2023-02-09 19:25:00': {'1. open': '133.7500',
#   '2. high': '133.7500',
#   '3. low': '133.7500',
#   '4. close': '133.7500',
#   '5. volume': '1101'},
#  '2023-02-09 17:30:00': {'1. open': '133.7500',
#   '2. high': '133.7500',
#   '3. low': '133.7500',
#   '4. close': '133.7500',
#   '5. volume': '1639'},
#  '2023-02-09 17:25:00': {'1. open': '134.0000',
#   '2. high': '134.0000',
#   '3. low': '134.0000',
#   '4. close': '134.0000',
#   '5. volume': '152'},
#  '2023-02-09 17:20:00': {'1. open': '134.0000',
#   '2. high': '134.0000',
#   '3. low': '134.0000',
#   '4. close': '134.0000',
#   '5. volume': '104'},
#  '2023-02-09 16:40:00': {'1. open': '133.7000',
#   '2. high': '133.7000',
#   '3. low': '133.7000',
#   '4. close': '133.7000',
#   '5. volume': '294'},
#  '2023-02-09 16:15:00': {'1. open': '133.5000',
# ...

# %%
#попробуем создать датафрэйм
test = pd.DataFrame(data['Time Series (5min)'])
test
# Out:
#           2023-02-09 19:45:00 2023-02-09 19:25:00 2023-02-09 17:30:00  \
# 1. open              133.7500            133.7500            133.7500
# 2. high              133.7500            133.7500            133.7500
# 3. low               133.7500            133.7500            133.7500
# 4. close             133.7500            133.7500            133.7500
# 5. volume                 100                1101                1639
#
#           2023-02-09 17:25:00 2023-02-09 17:20:00 2023-02-09 16:40:00  \
# 1. open              134.0000            134.0000            133.7000
# 2. high              134.0000            134.0000            133.7000
# 3. low               134.0000            134.0000            133.7000
# 4. close             134.0000            134.0000            133.7000
# 5. volume                 152                 104                 294
#
#           2023-02-09 16:15:00 2023-02-09 16:10:00 2023-02-09 16:05:00  \
# ...

# %%
#Сделаем красивее
test = test.T
test
# Out:
#                       1. open   2. high    3. low  4. close 5. volume
# 2023-02-09 19:45:00  133.7500  133.7500  133.7500  133.7500       100
# 2023-02-09 19:25:00  133.7500  133.7500  133.7500  133.7500      1101
# 2023-02-09 17:30:00  133.7500  133.7500  133.7500  133.7500      1639
# 2023-02-09 17:25:00  134.0000  134.0000  134.0000  134.0000       152
# 2023-02-09 17:20:00  134.0000  134.0000  134.0000  134.0000       104
# ...                       ...       ...       ...       ...       ...
# 2023-02-09 08:45:00  134.8600  134.8600  134.8600  134.8600       600
# 2023-02-09 08:30:00  135.0000  135.0000  135.0000  135.0000       101
# 2023-02-09 08:05:00  135.2490  135.2500  134.9500  134.9500      3425
# 2023-02-09 08:00:00  135.0000  135.0000  135.0000  135.0000       999
# 2023-02-09 07:55:00  135.1000  135.1000  135.1000  135.1000      1160
#
# [100 rows x 5 columns]

# %%
#Сложим количество бумаг, чтобы понять оборот
test['5. volume'].sum()
# Out:
# '...'

# %%
#Пробелм в том, что тип данных в колонке не int
test.dtypes
# Out:
# 1. open      object
# 2. high      object
# 3. low       object
# 4. close     object
# 5. volume    object
# dtype: object

# %%
#Переведем данные в нужный тип
test['5. volume'] = test['5. volume'].astype('int')
test.dtypes
# Out:
# 1. open      object
# 2. high      object
# 3. low       object
# 4. close     object
# 5. volume     int32
# dtype: object

# %%
#Повторим команду
test['5. volume'].sum()
# Out:
# 3190420

# %% [markdown]
# - Получение данных корректно
#
# 1 - для того, чтобы скачать данные, разработчики предоставляют все возможности и прописывают описание, как это сделать.
# 2 - возвращаемся на сайт: https://www.alphavantage.co/documentation/ и копируем следующий код:

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&apikey=demo'
r = requests.get(url)
data2 = r.json()

print(data2)
# Out:
# {'Meta Data': {'1. Information': 'Intraday (5min) open, high, low, close prices and volume', '2. Symbol': 'IBM', '3. Last Refreshed': '2023-02-09 19:45:00', '4. Interval': '5min', '5. Output Size': 'Compact', '6. Time Zone': 'US/Eastern'}, 'Time Series (5min)': {'2023-02-09 19:45:00': {'1. open': '133.7500', '2. high': '133.7500', '3. low': '133.7500', '4. close': '133.7500', '5. volume': '100'}, '2023-02-09 19:25:00': {'1. open': '133.7500', '2. high': '133.7500', '3. low': '133.7500', '4. close': '133.7500', '5. volume': '1101'}, '2023-02-09 17:30:00': {'1. open': '133.7500', '2. high': '133.7500', '3. low': '133.7500', '4. close': '133.7500', '5. volume': '1639'}, '2023-02-09 17:25:00': {'1. open': '134.0000', '2. high': '134.0000', '3. low': '134.0000', '4. close': '134.0000', '5. volume': '152'}, '2023-02-09 17:20:00': {'1. open': '134.0000', '2. high': '134.0000', '3. low': '134.0000', '4. close': '134.0000', '5. volume': '104'}, '2023-02-09 16:40:00': {'1. open': '133.7000', '
# ...

# %%
#Ключи у нас остались теже
data.keys()
# Out:
# dict_keys(['Meta Data', 'Time Series (5min)'])

# %%
#Повторим команду получения суммы операций
#Как мы видим, нам не пришлось заниматься обработкой данных и т.д.
test['5. volume'].sum()
# Out:
# 3190420

# %%
data2
# Out:
# {'Meta Data': {'1. Information': 'Intraday (5min) open, high, low, close prices and volume',
#   '2. Symbol': 'IBM',
#   '3. Last Refreshed': '2023-02-09 19:45:00',
#   '4. Interval': '5min',
#   '5. Output Size': 'Compact',
#   '6. Time Zone': 'US/Eastern'},
#  'Time Series (5min)': {'2023-02-09 19:45:00': {'1. open': '133.7500',
#    '2. high': '133.7500',
#    '3. low': '133.7500',
#    '4. close': '133.7500',
#    '5. volume': '100'},
#   '2023-02-09 19:25:00': {'1. open': '133.7500',
#    '2. high': '133.7500',
#    '3. low': '133.7500',
#    '4. close': '133.7500',
#    '5. volume': '1101'},
#   '2023-02-09 17:30:00': {'1. open': '133.7500',
#    '2. high': '133.7500',
#    '3. low': '133.7500',
#    '4. close': '133.7500',
#    '5. volume': '1639'},
#   '2023-02-09 17:25:00': {'1. open': '134.0000',
#    '2. high': '134.0000',
#    '3. low': '134.0000',
#    '4. close': '134.0000',
#    '5. volume': '152'},
#   '2023-02-09 17:20:00': {'1. open': '134.0000',
# ...

# %% [markdown]
# - резюме:
# Формат JSON частенько встречает в клиент-серверном взаимодействии, поэтому его лучше знать. Не всегда, но часто.

# %% [markdown]
# # Практическая часть

# %% [markdown]
# ## Задачка 1
# Скачайте набор данных в формате JSON. Набор данных позволяет получить информацию о видах билетов и тарифах на проезд в метрополитене и монорельсе, наземном пассажирском транспорте и пригородном железнодорожном транспорте города Москвы.
#
# Источник данных: Портал открытых данных Правительства Москвы: Тарифы на проезд в городском пассажирском транспорте
#
# Скачайте файл JSON. Загрузите данные в датафрейм и определите самый дешевый тариф. Стоимость указана в столбце TicketCost, а наименование тарифа NameOfTariff
#
# В поле ответа вставьте значение из столбца NameOfTariff

# %%
#Комментарий от меня: чтобы получить корректные данные. необходимо было
#произвести кодировку encoding="windows-1251"

d = pd.read_json('Z:\\Programming\\DataSciense\\Stepik_Pandas_Numpy\\Step_4.4._Задачка1.json',
                encoding="windows-1251")

# %%
d.loc[d['TicketCost'] == d['TicketCost'].min(), ['NameOfTariff']]
# Out:
#           NameOfTariff
# 17  «Разовый» льготный

# %% [markdown]
# ## Задачка 2
# Возвращаемся к выгрузке про пользователей из социальной сети. Снова загрузите ее в датафрейм, оставьте только столбцы username, name, sex и сохраните в формате json (кодировка utf8). Сохранение выполните таким образом чтобы ключами были названия колонок, а значениями вложенные словари, которые будут хранить лейбл строки и само значение:
# ![](https://ucarecdn.com/2bb216bc-872d-4469-b16a-c65d661c1e5a/)
# Когда функция to_json сохранит файл - загружайте на степик. Дополнительно форматировать результат для лучшей читаемости не следует. Чтобы тестовая система приняла результат - в файле .json должна быть всего одна строка.

# %%
d2 = pd.read_csv('Z:\\Programming\\DataSciense\\Stepik_Pandas_Numpy\\Step.4.4_Задача2.csv', sep = ';')
d2d
# Out:
#                                 job          company          ssn  \
# 0                   Records manager    Duncan-Garcia  241-62-8803
# 1               Mental health nurse         Rose-Lee  899-12-4937
# 2    Furniture conservator/restorer   Potts and Sons  261-41-9484
# 3                  Ambulance person       Rivera Inc  201-43-6181
# 4        Contracting civil engineer   Hatfield Group  878-83-6667
# ..                              ...              ...          ...
# 195            Journalist, magazine   Sanchez-Gaines  875-62-2622
# 196    Fast food restaurant manager  Clarke and Sons  765-06-4388
# 197              Surveyor, quantity     Clarke-Sloan  145-26-8248
# 198       Psychologist, counselling       Flores LLC  200-23-4183
# 199                    Metallurgist   Ochoa and Sons  368-59-9211
#
#                                              residence  \
# 0             309 Danielle Cliffs\nNorth Amy, NC 69960
# 1                     Unit 5929 Box 0845\nDPO AE 45149
# ...

# %%
d2_json = d2[['username', 'name', 'sex']]
d2_json
# Out:
#              username              name sex
# 0         lambertemma        Stacy Reed   F
# 1               greid      Carol Farley   F
# 2        scottmercado  Russell Whitaker   M
# 3           kristin75    Maureen Powers   F
# 4             lhansen   Edward Mcdonald   M
# ..                ...               ...  ..
# 195  johnsongwendolyn   Matthew Simpson   M
# 196      elijahlittle     Joshua Landry   M
# 197          robert89  Kimberly Cameron   F
# 198            todd08    Suzanne Garner   F
# 199      joshuaforbes       Jesus Clark   M
#
# [200 rows x 3 columns]

# %%
d2_json.to_json('Z:\\Programming\\DataSciense\\Stepik_Pandas_Numpy\\Step.4.4_Задача2.json')
